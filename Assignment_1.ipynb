# %% [markdown]
# <a href="https://colab.research.google.com/github/SM-Sowrov6/ML-Bootcamp/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: **Md S M Sowrov**

# %%
# Problem 1
# Declare variables of different data types
# ==========================================

name = "Sowrov"
age = 23
height = 1.75
is_student = True
nothing = None

print(name, age, height, is_student, nothing)
# Out:
# Sowrov 23 1.75 True None

# %%
# Problem 2
# Convert data types and check types
# ==========================================

x = '42'
y = 3.9
z = True

x_int = int(x)
y_int = int(y)
z_str = str(z)

print(x_int, type(x_int))
print(y_int, type(y_int))
print(z_str, type(z_str))
# Out:
# 42 <class 'int'>
# 3 <class 'int'>
# True <class 'str'>

# %%
# Problem 3
# Multiple assignment and swapping
# ==========================================

a, b, c = 10, 20, 30

print("Before Swap:", a, b, c)

a, c = c, a

print("After Swap:", a, b, c)
# Out:
# Before Swap: 10 20 30
# After Swap: 30 20 10

# %%
# Problem 4
# Demonstrate dynamic typing
# ==========================================

x = 10
print(x, type(x))

x = "hello"
print(x, type(x))

x = 3.14
print(x, type(x))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
# Problem 5
# Type conversion examples
# ==========================================

print(bool(0))          # False because 0 is falsy
print(bool(''))         # False because empty string is falsy
print(bool('hello'))    # True because non-empty string is truthy
print(bool(99))         # True because non-zero number is truthy
print(int(True))        # 1
print(int(False))       # 0
print(float('3.14'))    # 3.14
# Out:
# False
# False
# True
# True
# 1
# 0
# 3.14

# %%
# Problem 6
# Arithmetic operations
# ==========================================

a = 15
b = 4

print(f"Addition: {a+b}")
print(f"Subtraction: {a-b}")
print(f"Multiplication: {a*b}")
print(f"Division: {a/b}")
print(f"Floor Division: {a//b}")
print(f"Modulus: {a%b}")
print(f"Power: {a**b}")
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Power: 50625

# %%
# Problem 7
# Augmented assignment operators
# ==========================================

x = 100

x -= 25
print("After -= 25:", x)

x *= 2
print("After *= 2:", x)

x //= 3
print("After //= 3:", x)

x %= 7
print("After %= 7:", x)

x = 2
print("After = 2:", x)
# Out:
# After -= 25: 75
# After *= 2: 150
# After //= 3: 50
# After %= 7: 1
# After = 2: 2

# %%
# Problem 8
# Compare == and is
# ==========================================

a = 15
b = 15
c = [1, 2]
d = [1, 2]

print(a == b)
print(a is b)

print(c == d)
print(c is d)

# == compares values
# is compares memory locations
# Out:
# True
# True
# True
# False

# %%
# Problem 9
# Logical operators
# ==========================================

num = 25
print("Between 10 and 50:", num >= 10 and num <= 50)

text = "yes"
print("Yes or No:", text == "yes" or text == "no")

n = 7
print("Not divisible by 2:", not (n % 2 == 0))
# Out:
# Between 10 and 50: True
# Yes or No: True
# Not divisible by 2: True

# %%
# Problem 10
# Membership operators
# ==========================================

print("'py' in 'python':", "py" in "python")
print("'z' not in 'python':", "z" not in "python")

numbers = [1, 3, 5, 7, 9]

print("7 in list:", 7 in numbers)
print("4 not in list:", 4 not in numbers)
# Out:
# 'py' in 'python': True
# 'z' not in 'python': True
# 7 in list: True
# 4 not in list: True

# %%
# Problem 11
# String methods
# ==========================================

s = "  python programming  "

stripped = s.strip()

print(stripped)
print(stripped.upper())
print(stripped.title())
print(stripped.replace("python", "data"))
print(len(stripped))
# Out:
# python programming
# PYTHON PROGRAMMING
# Python Programming
# data programming
# 18

# %%
# Problem 12
# Split and Join
# ==========================================

text = "Data,Science,Machine,Learning"

items = text.split(",")

print(items)
print(items[1])
print(len(items))
print(" → ".join(items))
# Out:
# ['Data', 'Science', 'Machine', 'Learning']
# Science
# 4
# Data → Science → Machine → Learning

# %%
# Problem 13
# String slicing
# ==========================================

sentence = "Hello World Python"

print(sentence[:5])
print(sentence[-6:])
print(sentence[::2])
print(sentence[::-1])
# Out:
# Hello
# Python
# HloWrdPto
# nohtyP dlroW olleH

# %%
# Problem 14
# String methods
# ==========================================

word = "Banana"

print(word.find('a'))
print(word.count('a'))
print(word.startswith('Ba'))
print(word.endswith('na'))
print(word.isdigit())
print("12345".isdigit())
print("123a5".isdigit())
# Out:
# 1
# 3
# True
# True
# False
# True
# False

# %%
# Problem 15
# String formatting styles
# ==========================================

product = "Laptop"
price = 75000.5
discount = 10

# f-string
print(f"Product: {product} | Price: {price:.2f} | Discount: {discount}%")

# format()
print("Product: {} | Price: {:.2f} | Discount: {}%".format(product, price, discount))

# % operator
print("Product: %s | Price: %.2f | Discount: %d%%" % (product, price, discount))
# Out:
# Product: Laptop | Price: 75000.50 | Discount: 10%
# Product: Laptop | Price: 75000.50 | Discount: 10%
# Product: Laptop | Price: 75000.50 | Discount: 10%

# %%
# Problem 16
# Input name and birth year
# ==========================================

name = input("Enter your name: ")
birth_year = int(input("Enter your birth year: "))

age = 2025 - birth_year

print(f"Hello {name}! You are approximately {age} years old.")
# Out:
# Enter your name: Sowrov
# Enter your birth year: 2002
# Hello Sowrov! You are approximately 23 years old.

# %%
# Problem 17
# Rectangle area and perimeter calculator
# ==========================================

length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width
perimeter = 2 * (length + width)

print(f"Area: {area:.2f}")
print(f"Perimeter: {perimeter:.2f}")
# Out:
# Enter length: 23
# Enter width: 45
# Area: 1035.00
# Perimeter: 136.00

# %%
# Problem 18
# Grade calculator
# ==========================================

score = int(input("Enter score (0-100): "))

if 90 <= score <= 100:
    grade = "A+"
elif 80 <= score <= 89:
    grade = "A"
elif 60 <= score <= 79:
    grade = "B"
elif 40 <= score <= 59:
    grade = "C"
else:
    grade = "F"

print("Grade:", grade)

if score >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter score (0-100): 56
# Grade: C
# Pass

# %%
# Problem 19
# Login system
# ==========================================

correct_username = "Sowrov795"
correct_password = "Sowrov1234"

username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username:
    if password == correct_password:
        print("Access Granted")
    else:
        print("Wrong Password")
else:
    print("User Not Found")
# Out:
# Enter username: Sowrov795
# Enter password: Sowrov1234
# Access Granted

# %%
# Problem 20
# Positive/Negative/Zero and Even/Odd
# ==========================================

num = int(input("Enter a number: "))

result = "Positive" if num > 0 else ("Negative" if num < 0 else "Zero")

print(result)

if num != 0:
    if num % 2 == 0:
        print("Even")
    else:
        print("Odd")
# Out:
# Enter a number: 45
# Positive
# Odd
